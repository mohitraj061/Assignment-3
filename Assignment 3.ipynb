# %% [raw]
# Ques 1.) Why are functions advantageous to have in your programs ?
#
# Solution :
#
# Functions are advantageous to have in programs for several reasons:
#
# 1.) Reusability : Functions allow you to encapsulate a specific set of instructions and logic into
#     a single block of code that can be reused throughout the program. By defining a function, you
#     can call it multiple times from different parts of your program without having to repeat the
#     same code, making your program more efficient, modular and easier to maintain.
#
# 2.) Modularity : Functions promote modular programming by breaking down complex tasks into smaller,
#     more manageable pieces. Each function can be responsible for a specific task or a small part of
#     the overall program. This modular approach enhances code organization, readability, and maintainability.
#     It also enables different team members to work on different functions simultaneously, fostering
#     collaboration.
#
# 3.) Abstraction : Functions provide a level of abstraction, allowing you to focus on the high-level
#     functionality of your program without worrying about the implementation details of individual
#     functions. By using well-designed function interfaces, you can hide the underlying implementation
#     complexity and provide a simplified interface for other parts of the program to interact with.
#
# 4.) Code organization and readability : Functions help in structuring your code by logically dividing it
#     into smaller, self-contained units. This improves code organization and makes it easier to navigate
#     and understand. With functions, you can give meaningful names to different parts of your program,
#     making it more readable and easier to debug.
#
# 5.) Code reuse and maintenance : Functions promote code reuse, which can save you time and effort.
#     Instead of duplicating code throughout your program, you can define functions once and reuse
#     them whenever needed. This reduces code redundancy and makes maintenance and updates more manageable.
#     If a bug is found or an improvement is needed, you only have to modify the function in one place
#     and the changes will propagate throughout the program.
#
# 6.) Testing and debugging : Functions simplify the testing and debugging process. Since functions
#     encapsulate specific functionality, they can be tested in isolation, making it easier to identify
#     and fix issues. This modular approach allows for more focused and targeted testing, as well as
#     easier unit testing.
#
# Overall, using functions in your programs promotes code reuse, modularity, organization, and abstraction,
# leading to more efficient and maintainable code.

# %% [raw]
# Ques 2.) When does the code in a function run : when it's specified or when it's called ?
#
# Solution :
#
# The code inside a function runs when the function is called.
#
# When you define a function, you are essentially creating a reusable block of code with a specific name
# and a defined set of instructions. However, the code inside the function is not executed immediately upon
# defining the function. It only runs when the function is called or invoked.
#
# To execute the code within a function, you need to call the function by using its name followed by
# parentheses (). When the function is called, the program flow jumps to the function's definition and the
# code inside the function is executed sequentially from top to bottom. Once the function's code execution is
# complete, the program flow returns to the point where the function was called and the program continues
# executing from there.
#
# Here's an example to illustrate the concept :
#
# def greet():
#     print("Hello, Sudh")
# greet()
#
# In the example above, the code inside the greet() function is not executed when the function is defined.
# It only runs when the function is called using greet(). So, in this case, "Hello, Sudh" will be printed
# when the greet() function is called.
#
# It's important to note that functions can be called multiple times from different parts of the program,
# allowing reuse the same block of code whenever needed.

# %% [raw]
# Ques 3.) What statement creates a function ?
#
# Solution :
#
# In most programming languages, including Python, the def statement is used to create a function.
#
# The def statement is short for "define" and is followed by the name of the function, parentheses () and
# a colon ":" The body of the function, which contains the code to be executed when the function is called, is
# indented below the def statement.
#
# Here's an example of how to create a function using the def statement in Python :
#
# def greet():
#     print("Hello, Mohit")
#
# In the example above, the def statement is used to define a function named greet(). This function does not
# take any arguments and consists of a single statement that prints "Hello, Mohit" to the console.
#
# After defining the function, you can call it by using its name followed by parentheses ()
# When the function is called, the code inside the function's body will be executed, and "Hello, world!" will
# be printed to the console.

# %% [raw]
# Ques 4.) What is the difference between a function and a function call ?
#
# Solution :
#
# In programming, a function is a block of code that performs a specific task or a set of tasks. It is a reusable
# piece of code that can be called or invoked from different parts of a program. A function typically takes some
# input, called arguments or parameters, performs certain operations, and optionally returns a result.
#
# On the other hand, a function call is the actual invocation or execution of a function. When you make a function
# call, you are instructing the program to execute the code inside the function. A function call consists of the
# function name followed by parentheses, and may include arguments inside the parentheses if the function expects any.
#
# Here's an example to illustrate the difference :
#
# # Function definition
# def greet(name):
#     print("Hello, " + name + "!")
#
# # Function call
# greet("Alice")
#
# In the code snippet above, greet is a function that takes a parameter name and prints a greeting message. The function
# is defined using the def keyword. The function call greet("Alice") invokes the greet function and passes the argument
# "Alice" as the value for the name parameter. As a result, the program will print "Hello, Alice!".
#
# To summarize, a function is a defined block of code that performs a specific task, while a function call is the actual
# execution of that function with specific arguments or parameters.

# %% [raw]
# Ques 5.) How many global scopes are there in a Python program ? How many local scopes ?
#
# Solution :
#
# The global scope refers to the outermost level of the program, where variables, functions, and classes are defined
# outside of any function or class definition. The global scope is accessible from anywhere in the program, and variables
# defined in this scope are considered global variables.
#
# Local scopes, on the other hand, are created whenever a function or a class method is invoked. Each function call
# creates its own local scope, which is separate from the global scope. Local scopes are used to store variables that
# are specific to the function or method being executed. These variables are called local variables and are only
# accessible within their respective scopes.
#
# It's important to note that local scopes are hierarchical. Each nested function call creates a new local scope, which
# is stacked on top of the previous scopes. When a variable is referenced within a scope, Python first looks for that
# variable in the local scope. If it's not found, Python continues to search in the higher scopes until it reaches the
# global scope.
#
# To summarize:
#
# There is one global scope in a Python program.
# Each function call creates its own local scope.
# Local scopes are hierarchical and stacked on top of each other.
# Variables defined in the global scope are accessible from anywhere in the program.
# Variables defined in a local scope are only accessible within that scope and its nested scopes.

# %% [raw]
# Ques 6.) What happens to variables in a local scope when the function call returns ?
#
# Solution :
#
# When a function call returns in Python, the local scope associated with that function is destroyed, and any variables
# defined within that scope are deallocated from memory. This process is known as variable scope and lifetime management.
#
# Here's an example to illustrate this behavior:
#
# def my_function():
#     x = 10  # Local variable
#
#     # Other code...
#
#     return x
#
# result = my_function()
# print(result)  # Output: 10
#
# print(x)  # NameError: name 'x' is not defined
#
#
# In the example above, the function my_function() defines a local variable x with a value of 10. When the function is
# called and executed, the variable x exists within the local scope of that function. The function then returns the value
# of x, which is assigned to the variable result in the global scope.
#
# However, once the function call returns, the local scope of my_function() is destroyed, and the variable x is no longer
# accessible. If you try to access x outside the function, as demonstrated in the last line of the example, you will
# encounter a NameError because x is not defined in the global scope.
#
# This behavior ensures that local variables are temporary and only exist within the scope of the function where they are
# defined. It helps maintain encapsulation and prevents conflicts between variables in different scopes.

# %% [raw]
# Ques 7.) What is the concept of a return value ? Is it possible to have a return value in an expression ?
#
# Solution :
#
# The concept of a return value is associated with functions in programming. A return value is the value that a function
# sends back or "returns" to the caller after executing its code. It allows a function to provide a result or output that
# can be utilized by the calling code.
#
# When a function encounters a return statement, it evaluates the expression following the return keyword and then exits
# the function, passing the evaluated value back to the caller. The return value can be of any data type, such as numbers,
# strings, booleans, lists, or even more complex objects.
#
# Here's an example :
#
# def add_numbers(a, b):
#     return a + b
#
# result = add_numbers(3, 5)
# print(result)  # Output: 8
#
# In the example above, the add_numbers() function takes two arguments a and b and returns their sum using the return
# statement. The function call add_numbers(3, 5) returns the value 8, which is assigned to the variable result. The print()
# statement then outputs the value of result, which is 8.
#
# Regarding second question, yes, it is possible to have a return value in an expression. In Python, we can directly
# use a function call within an expression or assign its return value to a variable. This allows you to use the return
# value immediately or incorporate it into further computations.
#
# Here's an example :
#
# def multiply_numbers(a, b):
#     return a * b
#
# result = multiply_numbers(2, 4) + multiply_numbers(3, 5)
# print(result)  # Output: 26
#
# In this example, the return values of two multiply_numbers() function calls are used within an expression. The function
# calls multiply_numbers(2, 4) and multiply_numbers(3, 5) return the values 8 and 15, respectively. These values are then
# added together to produce the final result of 26, which is printed

# %% [raw]
# Ques 8.) If a function does not have a return statement, what is the return value of a call to that function ?
#
# Solution :
#
# If a function does not have a return statement, the return value of a call to that function is None. In Python, when
# a function does not explicitly return a value using the return statement, it implicitly returns None by default.
#
# Here's an example to illustrate this:
#
# def my_function():
#     print("This function does not have a return statement.")
#
# result = my_function()
# print(result)
#
# Output:
#
# This function does not have a return statement.
# None
#
# In the example above, the my_function() does not have a return statement. When we call the function and assign its result
# to the variable result, it will receive None. Subsequently, when we print result, it will output None.

# %% [raw]
# Ques 9.) How do you make a function variable refer to the global variable ?
#
# Solution :
#
# To make a function variable refer to a global variable in Python, we can use the global keyword. The global keyword
# allows you to indicate that a variable within a function should refer to a global variable of the same name.
#
# Here's an example:
#
# my_variable = 10
#
# def my_function():
#     global my_variable  # Declare the variable as global
#     my_variable = 20   # Modify the global variable
#
# print(my_variable)     # Output: 10
# my_function()
# print(my_variable)     # Output: 20
#
# In the example above, we have a global variable my_variable initialized with the value 10. Inside the my_function(),
# we declare my_variable as global using the global keyword. This allows us to modify the global variable's value within
# the function. When we call my_function(), it changes the value of my_variable to 20. Finally, we print the value of
# my_variable before and after calling the function to observe the change.
#
# Keep in mind that using global variables should be done with caution, as it can make the code harder to understand
# and maintain. It is generally recommended to minimize the use of global variables and instead pass values as function
# parameters and return values as needed.

# %% [raw]
# Ques 10.) What is the data type of None ?
#
# Solution :
#
# The data type of None in Python is called NoneType.
#
# None represents the absence of a value or a null value in Python. It is often used to indicate the absence of a return
# value in functions that do not explicitly return anything. None is a singleton object, meaning there is only one
# instance of it in memory.
#
# We can check the type of None using the type() function :
#
#     print(type(None))  # Output: <class 'NoneType'>
#
# The output indicates that None is an instance of the NoneType class.

# %% [raw]
# Ques 11.) What does the sentence import areallyourpetsnamederic do ?
#
# Solution :
#
# The sentence "import areallyourpetsnamederic" by itself is not a valid Python code statement. It looks like a sentence
# or phrase and does not conform to the syntax rules of the Python language.
#
# In Python, the import statement is used to bring modules or specific items from modules into the current scope, allowing
# us to use the functionality provided by those modules. The statement should be followed by the name of the module we
# want to import.
#
# If there is a module named "areallyourpetsnamederic" available in the Python environment, then the sentence "import
# areallyourpetsnamederic" would attempt to import that module. However, it is highly unlikely that such a module exists
# in the standard Python library or any commonly used third-party libraries.

# %% [raw]
# Ques 12.) If you had a bacon() feature in a spam module, what would you call it after importing spam ?
#
# Solution :
#
# If we have a bacon() feature in a module called spam and we import the spam module, we can call the bacon() feature
# using the module name followed by the function name separated by a dot.
#
# Here's an example :
#
# import spam
# spam.bacon()  # Call the bacon() function from the spam module
#
# In the example above, the spam module is imported, and then the bacon() function is called using the syntax spam.bacon().
# This syntax allows you to access and utilize the features (functions, variables, classes, etc.) defined in the spam module.

# %% [raw]
# Ques 13.) What can you do to save a programme from crashing if it encounters an error ?
#
# Solution :
#
# To handle errors and prevent a program from crashing, we can use error handling techniques such as exception handling.
# Exception handling allows us to catch and handle exceptions that occur during the execution of the program.
#
# In Python, we can use a try-except block to catch and handle exceptions. The try block contains the code that might
# raise an exception, and the except block specifies how to handle the exception if one occurs. By using exception handling,
# we can gracefully handle errors and take appropriate actions instead of allowing the program to crash.
#
# Here's an example :
#
# try:
#     # Code that may raise an exception
#     result = 10 / 0  # Division by zero will raise a ZeroDivisionError
# except ZeroDivisionError:
#     # Handling the specific exception
#     print("Error: Division by zero is not allowed.")
#
# In the example above, the try block contains the code that performs a division operation, which may raise a ZeroDivisionError
# if the divisor is zero. In the except block, we catch the ZeroDivisionError specifically and handle it by printing an
# error message.
#
# By utilizing exception handling, we can catch different types of exceptions, handle them appropriately, log errors,
# display meaningful error messages, or take corrective actions to prevent the program from crashing. Additionally, we
# can use finally block to specify code that should be executed regardless of whether an exception occurred or not.

# %% [raw]
# Ques 14.) What is the purpose of the try clause ? What is the purpose of the except clause ?
#
# Solution :
#
# The try clause in Python is used to enclose the code that may potentially raise an exception. It allows us to specify a
# block of code where we anticipate an error might occur. The purpose of the try clause is to define a section of code that
# needs to be executed, and if an exception occurs within that code block, it provides a way to handle the exception gracefully.
#
# The except clause is used in conjunction with the try clause. It allows us to define how to handle specific exceptions
# that occur within the try block. If an exception occurs, the except block is executed, and we can specify the appropriate
# actions to take in response to the exception.
#
# Here's a general structure of a try-except block :
#
# try:
#     # Code that may raise an exception
#     # ...
# except SomeExceptionType:
#     # Code to handle the specific exception
#     # ...
# except AnotherExceptionType:
#     # Code to handle another specific exception
#     # ...
#
# In the example above, the try block contains the code that may raise an exception. The except block(s) specify the exception
# type(s) that we want to handle and provide the code to be executed when the corresponding exception occurs.
#
# The purpose of the try clause is to mark the section of code where an exception might occur. The purpose of the except clause
# is to define how to handle specific exceptions that occur within the try block, allowing us to take appropriate actions,
# log errors, display meaningful messages, or continue program execution in a controlled manner.
